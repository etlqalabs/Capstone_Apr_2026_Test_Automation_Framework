# %%
import pandas as pd

# %%
df = pd.read_json("supplier_data.json")

# %%
df1 = df.head(10)
df2 = df.head(5)

# %%
df1.equals(df2)
# Out:
# False

# %%
df3 = df1.apply(tuple,axis=1)

# %%
df3
# Out:
# 0    (1, ABC Distributors, John Doe, johndoe@abcdis...
# 1    (2, Global Goods Inc., Jane Smith, janesmith@g...
# 2    (3, GreenTech Solutions, Robert Johnson, rober...
# 3    (4, EuroWare, Emily White, emily.white@euro-wa...
# 4    (5, Pacific Products, Michael Brown, michael.b...
# 5    (6, Fresh Produce Co., Sarah Taylor, sarah.tay...
# 6    (7, TechCore Electronics, David Lee, david.lee...
# 7    (8, HanYang Trading, Laura King, laura.king@ha...
# 8    (9, Indo Supplies, James Williams, james@indos...
# 9    (10, LatAm Imports, Olivia Harris, olivia.harr...
# dtype: object

# %%
df4 = df2.apply(tuple,axis=1)

# %%
df4
# Out:
# 0    (1, ABC Distributors, John Doe, johndoe@abcdis...
# 1    (2, Global Goods Inc., Jane Smith, janesmith@g...
# 2    (3, GreenTech Solutions, Robert Johnson, rober...
# 3    (4, EuroWare, Emily White, emily.white@euro-wa...
# 4    (5, Pacific Products, Michael Brown, michael.b...
# dtype: object

# %%
df1[~df3.isin(df4)]
# Out:
#    supplier_id         supplier_name    contact_name  \
# 5            6     Fresh Produce Co.    Sarah Taylor
# 6            7  TechCore Electronics       David Lee
# 7            8       HanYang Trading      Laura King
# 8            9         Indo Supplies  James Williams
# 9           10         LatAm Imports   Olivia Harris
#
#                     contact_email     contact_phone country  rating  \
# 5   sarah.taylor@freshproduce.com   +33-1-7035-6789  France     4.4
# 6          david.lee@techcore.com   +81-3-4567-8901   Japan     4.9
# 7          laura.king@hanyang.com  +86-10-8888-7777   China     4.1
# 8          james@indosupplies.com  +91-22-2678-9101   India     4.3
# 9  olivia.harris@latamimports.com  +52-55-2345-6789  Mexico     4.5
#
#   last_order_date
# 5      2024-11-21
# 6      2024-11-23
# 7      2024-11-16
# 8      2024-11-25
# 9      2024-11-20
