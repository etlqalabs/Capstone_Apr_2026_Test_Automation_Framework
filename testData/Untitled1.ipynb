# %%
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle

# Pre-requite database connection

oracle_engine = create_engine("oracle+cx_oracle://system:admin@localhost:1521/xe")
mysql_engine = create_engine("mysql+pymysql://root:Admin%40143@localhost:3308/retail_dwh_apr_2026")

# %%
foreign_query = """select * from fact_sales"""
primary_query = """select * from stag_products"""
foreign_df = pd.read_sql(foreign_query,mysql_engine)
primary_df = pd.read_sql(primary_query, mysql_engine)

# %%
foreign_df
# Out:
#     sales_id  product_id  store_id  quantity  total_sales   sale_date
# 0         10         110         4         9        153.0  2024-09-10
# 1         11         101         4        15        210.0  2024-09-11
# 2         12         102         5         9        243.0  2024-09-12
# 3         13         103         6        10        220.0  2024-09-13
# 4         14         104         7         8        248.0  2024-09-14
# 5         15         105         4        12        132.0  2024-09-15
# 6         16         106         5         5        115.0  2024-09-16
# 7         17         107         6         3         78.0  2024-09-17
# 8         18         108         7         6        168.0  2024-09-18
# 9         19         109         8        11        220.0  2024-09-19
# 10        20         110         9         9        175.5  2024-09-20
# 11        21         101         1        14        217.0  2024-09-21
# ...

# %%
primary_df
# Out:
#    product_id        product_name     category  price  stock_quantity  \
# 0         101           iPhone 15  Smartphones    999              50
# 1         102  Samsung Galaxy S23  Smartphones    899              75
# 2         103         Dell XPS 13      Laptops   1200              30
# 3         104      MacBook Pro 14      Laptops   2000              25
# 4         105     Sony WH-1000XM5   Headphones    350             100
# 5         106       Nike Air Zoom     Sneakers    120             200
# 6         107      Samsung 55" TV  Electronics    700              40
# 7         108    Philips Hue Bulb   Smart Home     50             500
# 8         109     Fitbit Charge 5    Wearables    150             150
# 9         110   Kindle Paperwhite     eReaders    130              80
#
#      brand  rating
# 0    Apple     4.8
# 1  Samsung     4.7
# 2     Dell     4.6
# 3    Apple     4.9
# 4     Sony     4.7
# 5     Nike     4.5
# 6  Samsung     4.4
# 7  Philips     4.8
# ...

# %%
df = foreign_df[~foreign_df['product_id'].isin(primary_df['product_id'])]

# %%
assert df.empty,"There are some additional rows in foregin key column"

# %%
primary_df.isnull().values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 primary_df.isnull().values()
#
# TypeError: 'numpy.ndarray' object is not callable
